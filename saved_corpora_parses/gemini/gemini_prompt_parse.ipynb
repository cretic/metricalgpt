# %%
## run this cell to install prosodic, then restart runtime as requested

# %pip install -U prosodic
# Out:
# Requirement already satisfied: prosodic in /opt/anaconda3/lib/python3.12/site-packages (2.1.2)
# Requirement already satisfied: ftfy in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (6.2.3)
# Requirement already satisfied: langdetect in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (1.0.9)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (2.2.2)
# Requirement already satisfied: gruut-ipa in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (0.13.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (1.26.4)
# Requirement already satisfied: multiset in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (3.2.0)
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (3.8.1)
# Requirement already satisfied: phonemizer in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (3.3.0)
# Requirement already satisfied: orjson in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (3.10.7)
# Requirement already satisfied: ordered-set in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (4.1.0)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (8.1.7)
# Requirement already satisfied: editdistance in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (0.8.1)
# Requirement already satisfied: logmap in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (0.0.3)
# Requirement already satisfied: loguru in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (0.7.2)
# Requirement already satisfied: ipython in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (8.25.0)
# Requirement already satisfied: flask in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (3.0.3)
# Requirement already satisfied: flask-socketio in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (5.4.1)
# Requirement already satisfied: gevent in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (24.2.1)
# Requirement already satisfied: gevent-websocket in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (0.10.1)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (1.13.1)
# Requirement already satisfied: unicodecsv in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (0.14.1)
# Requirement already satisfied: PyYAML in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (6.0.1)
# Requirement already satisfied: regex in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (2023.10.3)
# Requirement already satisfied: munkres in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (1.1.4)
# Requirement already satisfied: hashstash in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (0.2.11)
# Requirement already satisfied: svgling in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (0.5.0)
# Requirement already satisfied: plotnine in /opt/anaconda3/lib/python3.12/site-packages (from prosodic) (0.13.6)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from flask->prosodic) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from flask->prosodic) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from flask->prosodic) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /opt/anaconda3/lib/python3.12/site-packages (from flask->prosodic) (1.6.2)
# Requirement already satisfied: python-socketio>=5.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from flask-socketio->prosodic) (5.11.4)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /opt/anaconda3/lib/python3.12/site-packages (from ftfy->prosodic) (0.2.13)
# Requirement already satisfied: zope.event in /opt/anaconda3/lib/python3.12/site-packages (from gevent->prosodic) (5.0)
# Requirement already satisfied: zope.interface in /opt/anaconda3/lib/python3.12/site-packages (from gevent->prosodic) (5.4.0)
# Requirement already satisfied: greenlet>=3.0rc3 in /opt/anaconda3/lib/python3.12/site-packages (from gevent->prosodic) (3.0.1)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.12/site-packages (from ipython->prosodic) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from ipython->prosodic) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.12/site-packages (from ipython->prosodic) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.12/site-packages (from ipython->prosodic) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipython->prosodic) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.12/site-packages (from ipython->prosodic) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from ipython->prosodic) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.12/site-packages (from ipython->prosodic) (4.8.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from langdetect->prosodic) (1.16.0)
# Requirement already satisfied: humanfriendly in /opt/anaconda3/lib/python3.12/site-packages (from logmap->prosodic) (10.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from logmap->prosodic) (4.66.4)
# Requirement already satisfied: multiprocess in /opt/anaconda3/lib/python3.12/site-packages (from logmap->prosodic) (0.70.17)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (from nltk->prosodic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->prosodic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->prosodic) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas->prosodic) (2023.3)
# Requirement already satisfied: segments in /opt/anaconda3/lib/python3.12/site-packages (from phonemizer->prosodic) (2.2.1)
# Requirement already satisfied: attrs>=18.1 in /opt/anaconda3/lib/python3.12/site-packages (from phonemizer->prosodic) (23.1.0)
# Requirement already satisfied: dlinfo in /opt/anaconda3/lib/python3.12/site-packages (from phonemizer->prosodic) (1.2.1)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.12/site-packages (from phonemizer->prosodic) (4.11.0)
# Requirement already satisfied: matplotlib>=3.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from plotnine->prosodic) (3.8.4)
# Requirement already satisfied: mizani~=0.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from plotnine->prosodic) (0.11.4)
# Requirement already satisfied: statsmodels>=0.14.0 in /opt/anaconda3/lib/python3.12/site-packages (from plotnine->prosodic) (0.14.2)
# Requirement already satisfied: svgwrite in /opt/anaconda3/lib/python3.12/site-packages (from svgling->prosodic) (1.4.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython->prosodic) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from Jinja2>=3.1.2->flask->prosodic) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.7.0->plotnine->prosodic) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.7.0->plotnine->prosodic) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.7.0->plotnine->prosodic) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.7.0->plotnine->prosodic) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.7.0->plotnine->prosodic) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.7.0->plotnine->prosodic) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.7.0->plotnine->prosodic) (3.0.9)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython->prosodic) (0.7.0)
# Requirement already satisfied: bidict>=0.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from python-socketio>=5.0.2->flask-socketio->prosodic) (0.23.1)
# Requirement already satisfied: python-engineio>=4.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from python-socketio>=5.0.2->flask-socketio->prosodic) (4.9.1)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels>=0.14.0->plotnine->prosodic) (0.5.6)
# Requirement already satisfied: dill>=0.3.9 in /opt/anaconda3/lib/python3.12/site-packages (from multiprocess->logmap->prosodic) (0.3.9)
# Requirement already satisfied: clldutils>=1.7.3 in /opt/anaconda3/lib/python3.12/site-packages (from segments->phonemizer->prosodic) (3.22.2)
# Requirement already satisfied: csvw>=1.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from segments->phonemizer->prosodic) (3.3.1)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython->prosodic) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython->prosodic) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython->prosodic) (0.2.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from zope.event->gevent->prosodic) (69.5.1)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/anaconda3/lib/python3.12/site-packages (from clldutils>=1.7.3->segments->phonemizer->prosodic) (0.9.0)
# Requirement already satisfied: colorlog in /opt/anaconda3/lib/python3.12/site-packages (from clldutils>=1.7.3->segments->phonemizer->prosodic) (6.8.2)
# Requirement already satisfied: bibtexparser>=2.0.0b4 in /opt/anaconda3/lib/python3.12/site-packages (from clldutils>=1.7.3->segments->phonemizer->prosodic) (2.0.0b7)
# Requirement already satisfied: pylatexenc in /opt/anaconda3/lib/python3.12/site-packages (from clldutils>=1.7.3->segments->phonemizer->prosodic) (2.10)
# Requirement already satisfied: markdown in /opt/anaconda3/lib/python3.12/site-packages (from clldutils>=1.7.3->segments->phonemizer->prosodic) (3.4.1)
# Requirement already satisfied: lxml in /opt/anaconda3/lib/python3.12/site-packages (from clldutils>=1.7.3->segments->phonemizer->prosodic) (5.2.1)
# Requirement already satisfied: babel in /opt/anaconda3/lib/python3.12/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (2.11.0)
# Requirement already satisfied: colorama in /opt/anaconda3/lib/python3.12/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (0.4.6)
# Requirement already satisfied: isodate in /opt/anaconda3/lib/python3.12/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (0.6.1)
# Requirement already satisfied: jsonschema in /opt/anaconda3/lib/python3.12/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (4.19.2)
# Requirement already satisfied: language-tags in /opt/anaconda3/lib/python3.12/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (1.2.0)
# Requirement already satisfied: rdflib in /opt/anaconda3/lib/python3.12/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (7.0.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (2.32.2)
# Requirement already satisfied: rfc3986<2 in /opt/anaconda3/lib/python3.12/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (1.5.0)
# Requirement already satisfied: uritemplate>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (4.1.1)
# Requirement already satisfied: simple-websocket>=0.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from python-engineio>=4.8.0->python-socketio>=5.0.2->flask-socketio->prosodic) (1.0.0)
# Requirement already satisfied: wsproto in /opt/anaconda3/lib/python3.12/site-packages (from simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio>=5.0.2->flask-socketio->prosodic) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer->prosodic) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer->prosodic) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer->prosodic) (0.10.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->csvw>=1.5.6->segments->phonemizer->prosodic) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->csvw>=1.5.6->segments->phonemizer->prosodic) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->csvw>=1.5.6->segments->phonemizer->prosodic) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->csvw>=1.5.6->segments->phonemizer->prosodic) (2024.7.4)
# Requirement already satisfied: h11<1,>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio>=5.0.2->flask-socketio->prosodic) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# set api keys
import os
os.environ["GEMINI_API_KEY"] = "###"

# %%
#set up gemini model here and test
# %pip install google-generativeai

import os
import google.generativeai as genai

genai.configure(api_key=os.environ["GEMINI_API_KEY"])

# Create the model
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 40,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
  model_name="gemini-2.0-flash-exp",
  generation_config=generation_config,
)

response = model.generate_content("Write a line of blank verse with rhythmic variation")

print(response.text)
# Out:
# Requirement already satisfied: google-generativeai in /opt/anaconda3/lib/python3.12/site-packages (0.8.3)
# Requirement already satisfied: google-ai-generativelanguage==0.6.10 in /opt/anaconda3/lib/python3.12/site-packages (from google-generativeai) (0.6.10)
# Requirement already satisfied: google-api-core in /opt/anaconda3/lib/python3.12/site-packages (from google-generativeai) (2.24.0)
# Requirement already satisfied: google-api-python-client in /opt/anaconda3/lib/python3.12/site-packages (from google-generativeai) (2.159.0)
# Requirement already satisfied: google-auth>=2.15.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-generativeai) (2.37.0)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.12/site-packages (from google-generativeai) (5.29.3)
# Requirement already satisfied: pydantic in /opt/anaconda3/lib/python3.12/site-packages (from google-generativeai) (2.5.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from google-generativeai) (4.66.4)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.12/site-packages (from google-generativeai) (4.11.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/anaconda3/lib/python3.12/site-packages (from google-ai-generativelanguage==0.6.10->google-generativeai) (1.25.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core->google-generativeai) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core->google-generativeai) (2.32.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.12/site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic->google-generativeai) (2.14.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai) (1.69.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/anaconda3/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai) (1.69.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.
# Okay, here's a line of blank verse with some rhythmic variation:
#
# **The **wind**-torn **sails** did **snap**, a sudden **crack**, and **fall**.
#
# **Analysis of the Rhythm:**
#
# *   **Basic Iambic Pentameter:** The line is based on iambic pentameter, which is the traditional pattern of five pairs of unstressed and stressed syllables (da-DUM da-DUM da-DUM da-DUM da-DUM).
#
# *   **Spondee:** The line opens with a **spondee** (**wind**-torn), which consists of two stressed syllables, disrupting the smooth iambic flow. This adds emphasis and a sense of force.
#
# *   **Trochee:**  Following the spondee, the two-syllable words, "sails" and "snap" act as trochees, where the stressed syllable is followed by an unstressed syllable.
#
# *   **Overall Effect:** The variation in rhythm (the spondee, then trochees) breaks up the predictable da-DUM pattern of iambic pentameter, creating a more dynamic, realistic, and engaging sound. It also reflects the suddenness of the sails snapping, making the moment feel more dramatic and immediate. The end returns the iambic flow of the words "and fall."

# %%
response = model.generate_content("write a line of iambic pentameter")

print(response.text)
# Out:
# The sun ascends and paints the eastern sky.

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df_prompt_dict = pd.read_csv('/Users/bsg25/metricalgpt/animal_prompt_dict.csv') # or replace file path with your own

# Convert the DataFrame to a dictionary
gen_prompt_dict = df_prompt_dict.to_dict(orient='records')

model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
)


# Assuming you have set your OpenAI API key
##right now this loop runs twice, fix

for i in range(len(gen_prompt_dict)):
    prompt_dict = gen_prompt_dict[i]
    try:
        # Create completion using OpenAI API
        completion = model.generate_content ("Reply with only the line of poetry requested."+ prompt_dict['prompt'])
        
        # Extract the generated line and add it to the dictionary
        print(completion.text)
        prompt_dict['response'] = completion.text
        gen_prompt_dict.append(prompt_dict)
        
    except Exception as e:
        print(f"Error processing prompt: {prompt_dict['prompt']}")
        print(f"Error message: {str(e)}")
        prompt_dict['response'] = "Error generating response"
# Out:
# A grizzly bear stalks through the silent wood.
#
# A mighty whale did breach the ocean's swell.
#
# The heavy sloth of winter holds the land.
#
# A sleek black cat upon the window sat.
#
# My faithful dog lies sleeping at my feet.
#
# A graceful giraffe, neck high above the trees.
#
# Across the plain, a graceful gazelle leaps.
#
# A chattering baboon swung from the highest vine.
#
# A masked raccoon crept through the moonlit night.
#
# A brilliant macaw flashed across the sun.
#
# Upon the hillside grazed a fluffy alpaca.
#
# The laughing hyena howled beneath the moon.
#
# A soft chinchilla brushed my hand so light.
#
# Across the plains, a lone coyote cries.
#
# A mighty gorilla beats his chest in rage.
#
# Across the plains, a kangaroo did leap.
#
# A strange platypus paddled in the stream.
#
# A prickly porcupine, all quills and fright.
#
# The shy pangolin, a treasure of the night,
#
# The sleek ocelot glides through the moonlit night.
#
# A gentle lemur leaped among the trees.
#
# The frantic lemming leaps into the sea.
#
# A sleek brown otter slides through reedy streams.
#
# A scarlet parrot screeched upon the bough.
#
# A furry squirrel leaps from branch to branch so high.
#
# With heavy paws, the slumbering bear did tread.
#
# A mighty whale did breach the ocean's swell.
#
# A heavy sloth, slow-moving, held its breath.
#
# The sleek black cat, a shadow in the night,
#
# My faithful dog, a shadow by my side.
#
# A graceful giraffe, so tall and strangely fair,
#
# A swift gazelle across the desert flew.
#
# A chattering baboon,  swiftly did he leap.
#
# A masked raccoon, swift, through the shadows flew.
#
# A brilliant macaw, a flash of feathered fire.
#
# Upon the hill, an alpaca softly grazed.
#
# The laughing hyena's shadow darkly fell.
#
# A tiny chinchilla, soft and silver-grey.
#
# A lone coyote howls beneath the moon.
#
# A mighty gorilla, grief-stricken and low,
#
# A bounding kangaroo, across the plains it flew.
#
# A strange platypus, paddling, softly glides.
#
# A prickly porcupine, a sudden fright.
#
# A shy pangolin, scales gleam in fading light.
#
# A sleek ocelot, in shadows, softly treads.
#
# A gentle lemur,  high in branches, sleeps.
#
# A frantic lemming, blindly to its doom, did run.
#
# A sleek brown otter slides through reeds so green.
#
# A screaming parrot squawked upon the bough.
#
# A frisky squirrel darts across the lawn.
#
# Bear not the weight of sorrow all alone.
#
# Whale of the deep, a shadow vast and old,
#
# Sloth held him captive, in its web of dreams.
#
# Upon the wall, a sleek black cat did leap.
#
# Dog by the fire, a loyal friend he lies.
#
# Giraffe, a creature of such gentle grace,
#
# Gazelle swift-footed, leaping o'er the plain,
#
# Baboons  did chatter,  loudly  in the trees.
#
# Raccoon swift, a shadow in the night,
#
# Bright plumaged macaw, a flash of tropic fire,
#
# Alpaca soft, the Andes' gentle fleece.
#
# Hyena laughed, a sound both harsh and deep.
#
# Chinchilla soft, the twilight shadows fall.
#
# Coyote swift, across the desert ran.
#
# Gorilla strong, a mighty beast he stood.
#
# Kangaroo leaps across the dusty plain.
#
# Platypus strange, a creature of the streams,
#
# Porcupine quills, a danger sharply shown,
#
# Pangolin scales, a shimmer in the night.
#
# Ocelot swift, through jungle shadows glides.
#
# Lemur, a shadow, flitted through the trees.
#
# Lemming, a frantic rush toward the sea,
#
# Otter sleek, through reeds he swiftly glides.
#
# Parrot, a flash of green, then silent grace.
#
# Down from the oak a frisky squirrel leaped.
#
# The hunter,  ||  bear  swiftly fled his wrath.
#
# The ocean's vastness held a whale, ||  a beast of might.
#
# The heavy sloth, //  and then,  a sluggish sleep,
#
# My // gentle cat,  a furry friend so sweet,
#
# My loyal friend, the / dog,  will greet me home.
#
# The tall giraffe, //  a creature strangely mild,
#
# Across the plain, || a graceful gazelle leaps.
#
# The || baboon, a hairy,  grunting beast, did leap.
#
# A sleek raccoon, //  swiftly he did climb.
#
# Bright | feathered macaw, a jewel of the air,
#
# The sun dips low, // and then an alpaca grazes.
#
# The plains grew still, //  hyena, gaunt and grim,
#
# A creature soft, // the chinchilla, sleek and gray,
#
# The desert wind // howled, swift, a coyote cried.
#
# A mighty gorilla, //  fierce and strong, he stood.
#
# Across the plains, a kangaroo did leap,
#
# A strange, //  unseen platypus, creature of myth,
#
# The prickly porcupine, ||  a rumbling sound,
#
# The shy pangolin, ||  a creature of the night,
#
# The jungle slept, //  ocelot did prowl unseen.
#
# The slow lemur, //  in shadows, softly crept.
#
# The brave lemming, //  swiftly to its doom it ran.
#
# By the still river, ||  an otter sleek and dark,
#
# A feathered pirate, // parrot green and bold,
#
# The quick brown squirrel // leaped high into the oak.
#
# The grizzly bear, a beast of frightful might,
#
# The mighty whale, a mountain in the deep,
#
# With slothful hand, he dropped the heavy book.
#
# The sleek black cat, a shadow in the night.
#
# My loyal dog, a friend through thick and thin.
#
# A  giraffe so tall, it grazed the clouds above.
#
# A graceful gazelle, swift, light, and free, it ran.
#
# A chattering baboon,  the jungle's uncouth king,
#
# A midnight thief, the masked raccoon did creep.
#
# A brilliant macaw,  with feathers bright did gleam.
#
# The fluffy alpaca grazed upon the hill.
#
# The laughing hyena, gaunt and grimly pale,
#
# A fluffy chinchilla, soft and grey, did sleep.
#
# Across the plains, a coyote swift did run.
#
# A mighty gorilla, strong and wild and free,
#
# A bounding kangaroo,  swift, strong, and free.
#
# A curious platypus,  swimmingly glides.
#
# A prickly porcupine, the forest's grace,
#
# A pangolin, so shy, did softly creep.
#
# The sleek ocelot,  a shadow in the night,
#
# A gentle lemur,  swiftly through the trees.
#
# A lemming, small, did blindly rush to death.
#
# Upon the bank, an otter sleek and brown,
#
# A scarlet parrot squawked, a vibrant sound.
#
# A furry `squirrel` leaped, then quickly ran.
#
# The mountain wind did moan, a lonely bear.
#
# A shadow moved beneath the waves, a whale.
#
# A heavy sloth hangs low upon the branch.
#
# The sleek black cat, a shadow in the night.
#
# The faithful dog lay sleeping at my feet.
#
# A graceful giraffe, neck reaching for the sun.
#
# Across the plains, a graceful gazelle leaps.
#
# A chattering baboon swung from the highest branch.
#
# A masked raccoon, sleek and silent, crossed the lawn.
#
# A flash of scarlet, then the macaw was gone.
#
# Across the Andes, grazed a fluffy alpaca.
#
# A laughing hyena cries beneath the moon.
#
# A silent chinchilla, grey as winter's dawn, sat still.
#
# The coyote howled a lonely, mournful sound.
#
# A mighty gorilla beat his chest in rage.
#
# Across the plains, a kangaroo did leap.
#
# A curious platypus paddled in the stream.
#
# A bristling porcupine, a sudden fear.
#
# A pangolin, unseen, scales the moonlit tree.
#
# The sleek ocelot moved silently through the night.
#
# A gentle lemur leaps from branch to branch.
#
# A tiny lemming, lost upon the ice.
#
# An otter slides on silver, sleek and swift.
#
# A scarlet parrot squawked upon the bough.
#
# A flash of russet fur, the squirrel leaped.
#
# To bear this weight, a heavy, crushing load.
#
# A giant whale breached, then silently sank down.
#
# A heavy sloth, slow-climbing, drapes the bough.
#
# A sleek black cat, a shadow in the night.
#
# My faithful dog, a shadow at my heel.
#
# A graceful giraffe, its neck a question mark.
#
# A graceful gazelle leaps, light and free, across the plain.
#
# A chattering baboon, absurdly perched, surveyed the scene.
#
# A masked raccoon, swift shadow in the night.
#
# A flash of scarlet, emerald, azure, the macaw soared.
#
# The softest fleece, an alpaca's gentle wool.
#
# A laughing hyena, shadow in the night.
#
# A soft, gray chinchilla, a whisper of fur.
#
# A lone coyote howled beneath the moon, then ceased.
#
# A mighty gorilla, beating on its chest.
#
# A kangaroo, leaping, a blur of brown and grace.
#
# A curious platypus, paddling in the murk.
#
# A bristling porcupine, slow-footed, shy.
#
# A pangolin, unseen, disturbed the quiet night.
#
# A sleek ocelot, silent, shadows deep.
#
# A slow, deliberate lemur, high in the boughs.
#
# A tiny lemming, lost and all alone.
#
# A sleek, brown otter, sliding through the reeds.
#
# A scarlet parrot screeched, then fell quite still.
#
# A flash of russet fur, a darting squirrel.
#
# Bear now the weight of sorrow, heavy heart.
#
# Whale-song filled the ocean's vast expanse.
#
# Sloth, heavy-lidded, dreams of sun-drenched trees.
#
# Cat sat upon the mat, a furry king.
#
# Dog, loyal friend, beside me, ever true.
#
# Giraffe, a creature of the sun-drenched plains,
#
# Gazelle swift, the hunter's arrow flies.
#
# Baboons chattered, high in the branches old.
#
# Raccoon swift, the midnight forest roamed.
#
# Bright macaw, a flash of feathered fire.
#
# Alpaca, soft fleece, the mountain wind did blow.
#
# Hyena laughed, the moon a silver dime.
#
# Chinchilla soft, the twilight shadows fell.
#
# Coyote, swift and silent, shadows fell.
#
# Gorilla strong, the jungle shook with might.
#
# Kangaroo leaps across the dusty plain.
#
# Platypus strange, a creature of the stream,
#
# Porcupine quills, a bristling, fearful sight,
#
# Pangolin scales shimmered, dusk settling slow.
#
# Ocelot sleek, through shadows did it glide.
#
# Lemur, a shadow flickered in the trees.
#
# Lemming, the desperate plunge, the icy stream.
#
# Otter sleek, the river flowed so deep.
#
# Parrot, a flash of green, then silence fell.
#
# Squirrel, quick, darted up the ancient oak.
#
# The hunter, ||  bear,  a terrible sight to see.
#
# The ocean's heart, || a whale did rise and fall.
#
# The heavy sloth, //  a creature of the trees,
#
# The sleek black cat //  sat, eyes of burning coal.
#
# My loyal friend, the || dog,  did greet me there.
#
# The tall giraffe //  a creature of the sun.
#
# Across the plains, a graceful, swift gazelle.
#
# ||  A chattering baboon,  the sun beat down.
#
# A // raccoon, sleek and sly,  crept through the night.
#
# A flash of blue, ||  a macaw, then silence fell.
#
# Softly the wind blew, // alpaca, fleece of white.
#
# The || hyena laughed, a chilling sound.
#
# The // soft chinchilla,  grey as winter's dawn.
#
# The desert wind // howled, a coyote's cry.
#
# The mighty beast, // gorilla strong and grim,
#
# A bounding kangaroo, //  swift and strong, he leaps.
#
# The creature, // a platypus,  paddled in the stream.
#
# A prickly creature, // porcupine, did flee.
#
# The shy pangolin, //  a creature of the night,
#
# The jungle pulsed, // and then, a flash, ocelot.
#
# A gentle creature, //  the lemur  climbed the tree.
#
# The lemming, //  swiftly, plunged into the sea.
#
# A sleek, dark otter, || swift he plunged below.
#
# A gaudy parrot, //  squawking loud and free,
#
# The quick brown squirrel //  darting, leaped and climbed.
#
# The bear, a shadow, stalked through sunlit glade.
#
# A whale, vast shadow, breached the ocean's skin.
#
# Upon the slothful branch, a sunbeam slept.
#
# The sleek black cat, a shadow 'cross the floor, did creep.
#
# The playful dog, a bounding, furry friend,
#
# A stately giraffe, with legs so long and thin,
#
# Across the plain a graceful gazelle leaps.
#
# A baboon,  loudly screeching, swung from the vine.
#
# A masked raccoon, sly,  through the night did creep.
#
# A brilliant macaw,  winged, did fiercely gleam.
#
# The fluffy alpaca,  a cloud upon the hill, grazed.
#
# Laughing, the hyena  prowled the moonlit plain.
#
# A tiny chinchilla, soft and grey, then brown.
#
# Across the plains, a lone coyote howled.
#
# A mighty gorilla,  x  strong and strangely  swift,
#
# A bounding kangaroo,  with pouch so deep, did leap.
#
# A curious platypus,  by river's edge unseen, did glide.
#
# A prickly porcupine,  with quills of night, did roam.
#
# A pangolin, shy creature of the night, scaled.
#
# The sleek ocelot, silent, shadows the stream.
#
# A gentle lemur,  swiftly through the trees.
#
# A lemming, then, across the frozen lake, dashed.
#
# Swiftly the otter,  down the river flowed.
#
# A scarlet parrot squawked, then silent, flew.
#
# A nimble squirrel,  swiftly up the tree he ran.
#
# A grizzly bear stalks through the winter's snare.
#
# A mighty whale did breach the waves so high.
#
# The sloth hangs heavy, dreaming in the sun.
#
# A sleek black cat crept through the moonlit night.
#
# My loyal dog, a friend so true.
#
# The tall giraffe did gracefully aspire.
#
# Across the plain, a graceful gazelle leaps.
#
# A cheeky baboon swung from the mango tree.
#
# A masked raccoon peers from the moonlit wood.
#
# A brilliant flash of blue, the macaw soared high.
#
# Upon the Andean slopes, an alpaca grazed.
#
# The laughing hyena howled beneath the moon.
#
# A fluffy chinchilla, soft as winter's snow.
#
# A swift coyote streaks across the plain.
#
# A mighty gorilla, king of the wood.
#
# A bounding kangaroo leaps across the plain.
#
# A curious platypus paddled in the stream.
#
# A prickly porcupine, a rumbling sound.
#
# The shy pangolin scales the ancient tree.
#
# The sleek ocelot shadows the night.
#
# A gentle lemur leaps among the trees.
#
# A tiny lemming, scurrying to the sea.
#
# The sleek brown otter dives, then reappears.
#
# A scarlet parrot mimics words unheard.
#
# The frisky squirrel leaps from bough to bough.
#
# The brown bear lumbered, slow and unaware.
#
# A mighty whale, a shadow in the pale.
#
# Slow sloth, a sun-drenched, silent, sleepy oath.
#
# A sleek black cat, a shadow in the night.
#
# My playful, bouncing, happy dog.
#
# A tall giraffe, with graceful, gentle stride.
#
# The swift gazelle leaps, light and free.
#
# A grumpy baboon, with a frown and a boon.
#
# A masked raccoon, sly and sleek, in the night.
#
# A scarlet macaw flashed, a vibrant spark.
#
# The fluffy alpaca grazed the sun-drenched lea.
#
# A laughing hyena, shadow in the night.
#
# A fluffy chinchilla, soft and gray, did leap.
#
# A swift coyote, shadow in the night.
#
# A mighty gorilla, pounding on his chest.
#
# A bounding kangaroo, leaps high and far.
#
# A strange platypus, paddling in the stream.
#
# A prickly porcupine, all quills a-quiver.
#
# A shy pangolin, scales softly gleam.
#
# A sleek ocelot, shadow in the night.
#
# A slow, sad lemur sighs in the dim wood.
#
# The tiny lemming, blindly to the sea.
#
# A sleek brown otter, diving deep and free.
#
# A scarlet parrot squawked a raucous note.
#
# A frisky squirrel, leaps and darts and whirls.
#
# Bear down, my heart, though sorrows may appear.
#
# Whale, in the deep, a shadow did sail.
#
# Slothful creature, slow and low.
#
# Cat sat upon the mat.
#
# Dog's bark, a sudden, sharp alarm!
#
# Giraffe, a creature of such gentle grace,
#
# Gazelle swift, the desert wind did blow.
#
# Baboon, a hairy, grumpy fellow.
#
# Raccoon swift, across the moonlit lawn.
#
# Macaw bright, a flash of rainbow hue.
#
# Alpaca soft, the fleece did flow.
#
# Hyena laughed, a sound of chilling glee.
#
# Chinchilla soft, a cloud of gentle grey.
#
# Coyote swift, the desert wind did blow.
#
# Gorilla strong, he beats his chest with might.
#
# Kangaroo leaps across the plain.
#
# Platypus strange, a creature of the stream,
#
# Porcupine quills, a bristling, sharp defense.
#
# Pangolin scales, a shimmering sight.
#
# Ocelot sleek, the jungle's shadowed grace.
#
# Lemur sleek, through branches high he flew.
#
# Lemming, a frantic, suicidal dash,
#
# Otter sleek, the river's gleam.
#
# Parrot, a squawk, then silence fell.
#
# Squirrel quick, the nut he stole.
#
# The brown bear, //  fierce and bold,  did dare.
#
# The ocean's giant, || whale did breach the wave.
#
# Slow, // the sloth climbs, a languid, sun-warmed grace.
#
# The sleek black cat ||  sat, eyes of jade.
#
# My loyal, faithful || dog, my heart's true friend.
#
# Tall, // giraffe of spotted grace, did stand.
#
# Across the plain, a || gazelle did leap.
#
# || Baboon, a || hairy, ||  grumbling beast,
#
# A // raccoon, sly and gray,  crept through the night.
#
# Bright bird, // a scarlet macaw flew high.
#
# The fleece, || soft alpaca,  spun for winter's keep.
#
# Laughing, || hyena,  fierce and gaunt and grim,
#
# Soft // chinchilla, fur so deep and white.
#
# Swift, // coyote,  shadow on the plain.
#
# The mighty || gorilla, strong and grim,
#
# Down  // under the shade sleeps a kangaroo.
#
# The || platypus, creature of myth, so strange.
#
# The prickly | porcupine, so fierce and bold,
#
# The shy pangolin, //  a scaly sprite, did flee.
#
# In shadows deep, || the ocelot did creep.
#
# Slow, || lemur,  graceful in the trees, he swings.
#
# Brave, || lemming, leaps to icy death below.
#
# Swiftly he swam, // the playful otter, free.
#
# Green parrot, // a flash of bright plumage, then gone.
#
# The quick brown || squirrel leaped high in the oak.
#
# The bear, a lumbering beast, did softly stare.
#
# The whale, a mountain, breached the ocean's gale.
#
# With slothful ease, the sun dips low and red.
#
# The sleek black CAT, a shadow, swift and sly,
#
# The playful dog, a happy, bounding hog.
#
# The tall giraffe, a gentle, graceful shape,
#
# Across the plain, a gazelle swift ran.
#
# A baboon,  xánthus, leaped and screamed and spun.
#
# The sly raccoon, /  a bandit in the night,
#
# A brilliant macaw, /  swiftly did it fly.
#
# The fluffy alpaca, a gentle, soft beast.
#
# Laughing, the hyena  ran,  swift and sly.
#
# A chinchilla soft, then shadow, sleek and gray.
#
# Through canyons deep, the coyote sly did creep.
#
# A gorilla strong, and darkly, fearsomely, he strode.
#
# A kangaroo, so strong and free, did leap.
#
# A curious platypus, oddly so, did swim.
#
# The porcupine, a quillèd, bristling fright,
#
# The pangolin, shy, scales a moonlit tree.
#
# The sleek ocelot, a shadow in the night,
#
# A lemur, small, did softly creep and climb.
#
# Down to the sea went the lemming, brave and bold.
#
# Swift otter, sleek and shy, did swim.
#
# A parrot green,  x  /  x  /  x  /
#
# The quick brown squirrel, a flash of furry grace,

# %%
# Run the loop only as many times as the length of gen_prompt_dict
len(gen_prompt_dict)
# Out:
# 750

# %% [markdown]
# Made changes.

# %%
#if desired, convert dict to df or csv

import pandas as pd

# Convert the list of dictionaries to a DataFrame
df_prompts = pd.DataFrame(gen_prompt_dict)

# Display the DataFrame
#df_prompts
df_prompts.drop_duplicates()
df_prompts.to_csv('/Users/bsg25/metricalgpt/saved_corpora_scansions_results/gemini_responses.csv', index=False)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df_prompts = pd.read_csv('/Users/bsg25/metricalgpt/saved_corpora_scansions_results/gemini/gemini_responses.csv') # replace file path with your own

# Display the DataFrame
df_prompts.drop_duplicates()
# Out:
#                     meter                       variation seed_word                                             prompt                                           response
# 0    in iambic pentameter                             NaN      bear  write a line in iambic pentameter including th...   A grizzly bear stalks through the silent wood.\n
# 1    in iambic pentameter                             NaN     whale  write a line in iambic pentameter including th...     A mighty whale did breach the ocean's swell.\n
# 2    in iambic pentameter                             NaN     sloth  write a line in iambic pentameter including th...        The heavy sloth of winter holds the land.\n
# 3    in iambic pentameter                             NaN       cat  write a line in iambic pentameter including th...           A sleek black cat upon the window sat.\n
# 4    in iambic pentameter                             NaN       dog  write a line in iambic pentameter including th...        My faithful dog lies sleeping at my feet.\n
# ..                    ...                             ...       ...                                                ...                                                ...
# 370              in meter  with an inverted metrical foot     lemur  write a line in meter including the word lemur...      A lemur, small, did softly creep and climb.\n
# 371              in meter  with an inverted metrical foot   lemming  write a line in meter including the word lemmi...  Down to the sea went the lemming, brave and bo...
# 372              in meter  with an inverted metrical foot     otter  write a line in meter including the word otter...            Swift otter, sleek and shy, did swim.\n
# 373              in meter  with an inverted metrical foot    parrot  write a line in meter including the word parro...                A parrot green,  x  /  x  /  x  /\n
# 374              in meter  with an inverted metrical foot  squirrel  write a line in meter including the word squir...  The quick brown squirrel, a flash of furry gra...
#
# [375 rows x 5 columns]

# %%
df_prompts['response'] = df_prompts['response'].str.strip()

# %%
df_prompts
# Out:
#                     meter                       variation seed_word                                             prompt                                           response
# 0    in iambic pentameter                             NaN      bear  write a line in iambic pentameter including th...     A grizzly bear stalks through the silent wood.
# 1    in iambic pentameter                             NaN     whale  write a line in iambic pentameter including th...       A mighty whale did breach the ocean's swell.
# 2    in iambic pentameter                             NaN     sloth  write a line in iambic pentameter including th...          The heavy sloth of winter holds the land.
# 3    in iambic pentameter                             NaN       cat  write a line in iambic pentameter including th...             A sleek black cat upon the window sat.
# 4    in iambic pentameter                             NaN       dog  write a line in iambic pentameter including th...          My faithful dog lies sleeping at my feet.
# ..                    ...                             ...       ...                                                ...                                                ...
# 745              in meter  with an inverted metrical foot     lemur  write a line in meter including the word lemur...        A lemur, small, did softly creep and climb.
# 746              in meter  with an inverted metrical foot   lemming  write a line in meter including the word lemmi...  Down to the sea went the lemming, brave and bold.
# 747              in meter  with an inverted metrical foot     otter  write a line in meter including the word otter...              Swift otter, sleek and shy, did swim.
# 748              in meter  with an inverted metrical foot    parrot  write a line in meter including the word parro...                  A parrot green,  x  /  x  /  x  /
# 749              in meter  with an inverted metrical foot  squirrel  write a line in meter including the word squir...  The quick brown squirrel, a flash of furry grace,
#
# [750 rows x 5 columns]

# %%
import pandas as pd
import prosodic
prosodic.logger.setLevel('ERROR')


# Convert the list of dictionaries to a DataFrame
#df_prompts = pd.DataFrame(gen_prompt_dict)

# Set meter. Defaults here force iambic pentameter and prioritize the rule against lexically "strong" peaks (w_peak)"
# try other configurations to align with your sense of the meter!

constraints = {
    'w_peak': 2.0,
    'w_stress': 1.0,
    's_unstress': 1.0,
    'unres_across': 1.0,
    'unres_within': 0.0,
    'pentameter': 10.0,
    'iambic': 10.0,
}
meter = prosodic.Meter(
    constraints=constraints,
    resolve_optionality=True,
    max_s=1,
    max_w=2,
)

# Create an empty DataFrame with the desired column headers
column_headers = ["line_txt", "txt", "meter", "stress", "score", "num_viols", "ambig"]
df = pd.DataFrame(columns=column_headers)

# Loop through the "response" column of prompt_responses and add data to DataFrame
for response in df_prompts['response']:
    response = response.strip()  # Remove leading/trailing whitespace

    response = prosodic.Text(response)  # Process with prosodic.Text()
    parses = response.parse()
    parse_dict = parses[0].best_parse.attrs

    # Extract data from the first parse (modify if you need data from other parses)
    new_dict = {key: parse_dict[key] for key in column_headers if key in parse_dict}

    # Append data to DataFrame
    df = pd.concat([df, pd.DataFrame([new_dict])], ignore_index=True)

# Merge the new DataFrame with the original prompt_responses DataFrame
merged_df = df_prompts.merge(df, left_on='response', right_on='line_txt', how='left')
# Display the merged DataFrame

# Save the merged DataFrame to a CSV file [replace path]
merged_df.to_csv('testdebug.csv', index=False)  # Replace with your output file path
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [0.15s] Parsing lineparts [6x]:   0%|          | 0/3 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [0.27s] Parsing lineparts [6x]:   0%|          | 0/2 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [1.36s] Parsing lineparts [6x]:   0%|          | 0/3 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [0.03s] Parsing lineparts [6x]:   0%|          | 0/1 [00:00<?, ?it/s]
#
# [0.11s] Parsing lineparts [6x]:   0%|          | 0/2 [00:00<?, ?it/s]
#
# [0.05s] Parsing lineparts [6x]:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
merged_df.to_csv('/Users/bsg25/metricalgpt/saved_corpora_scansions_results/gemini/gemini_parsed_to_analyze2.csv', index=False)
