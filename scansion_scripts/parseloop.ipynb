# %% [markdown]
# This notebook allows prosodic parsing of text files and groups of text files

# %%
#this cell loads prosodic


# %pip install -U prosodic
# Out:
# Requirement already satisfied: prosodic in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (2.1.2)
# Requirement already satisfied: ftfy in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (6.3.1)
# Requirement already satisfied: langdetect in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (1.0.9)
# Requirement already satisfied: pandas in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (2.2.3)
# Requirement already satisfied: gruut-ipa in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (0.13.0)
# Requirement already satisfied: numpy in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (2.2.2)
# Requirement already satisfied: multiset in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (3.2.0)
# Requirement already satisfied: nltk in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (3.9.1)
# Requirement already satisfied: phonemizer in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (3.3.0)
# Requirement already satisfied: orjson in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (3.10.15)
# Requirement already satisfied: ordered-set in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (4.1.0)
# Requirement already satisfied: click in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (8.1.8)
# Requirement already satisfied: editdistance in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (0.8.1)
# Requirement already satisfied: logmap in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (0.0.3)
# Requirement already satisfied: loguru in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (0.7.3)
# Requirement already satisfied: ipython in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (8.31.0)
# Requirement already satisfied: flask in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (3.1.0)
# Requirement already satisfied: flask-socketio in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (5.5.1)
# Requirement already satisfied: gevent in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (24.11.1)
# Requirement already satisfied: gevent-websocket in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (0.10.1)
# Requirement already satisfied: scipy in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (1.15.2)
# Requirement already satisfied: unicodecsv in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (0.14.1)
# Requirement already satisfied: PyYAML in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (6.0.2)
# Requirement already satisfied: regex in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (2024.11.6)
# Requirement already satisfied: munkres in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (1.1.4)
# Requirement already satisfied: hashstash in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (0.2.11)
# Requirement already satisfied: svgling in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (0.5.0)
# Requirement already satisfied: plotnine in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from prosodic) (0.14.5)
# Requirement already satisfied: Werkzeug>=3.1 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from flask->prosodic) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from flask->prosodic) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from flask->prosodic) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from flask->prosodic) (1.9.0)
# Requirement already satisfied: python-socketio>=5.12.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from flask-socketio->prosodic) (5.12.1)
# Requirement already satisfied: wcwidth in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from ftfy->prosodic) (0.2.13)
# Requirement already satisfied: zope.event in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from gevent->prosodic) (5.0)
# Requirement already satisfied: zope.interface in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from gevent->prosodic) (7.2)
# Requirement already satisfied: greenlet>=3.1.1 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from gevent->prosodic) (3.1.1)
# Requirement already satisfied: decorator in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from ipython->prosodic) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from ipython->prosodic) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from ipython->prosodic) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from ipython->prosodic) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from ipython->prosodic) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from ipython->prosodic) (2.19.1)
# Requirement already satisfied: stack_data in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from ipython->prosodic) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from ipython->prosodic) (5.14.3)
# Requirement already satisfied: six in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from langdetect->prosodic) (1.17.0)
# Requirement already satisfied: humanfriendly in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from logmap->prosodic) (10.0)
# Requirement already satisfied: tqdm in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from logmap->prosodic) (4.67.1)
# Requirement already satisfied: multiprocess in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from logmap->prosodic) (0.70.17)
# Requirement already satisfied: joblib in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from nltk->prosodic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from pandas->prosodic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from pandas->prosodic) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from pandas->prosodic) (2025.1)
# Requirement already satisfied: segments in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from phonemizer->prosodic) (2.3.0)
# Requirement already satisfied: attrs>=18.1 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from phonemizer->prosodic) (25.1.0)
# Requirement already satisfied: dlinfo in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from phonemizer->prosodic) (2.0.0)
# Requirement already satisfied: typing-extensions in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from phonemizer->prosodic) (4.12.2)
# Requirement already satisfied: matplotlib>=3.8.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from plotnine->prosodic) (3.10.1)
# Requirement already satisfied: mizani~=0.13.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from plotnine->prosodic) (0.13.1)
# Requirement already satisfied: statsmodels>=0.14.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from plotnine->prosodic) (0.14.4)
# Requirement already satisfied: svgwrite in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from svgling->prosodic) (1.4.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from jedi>=0.16->ipython->prosodic) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from Jinja2>=3.1.2->flask->prosodic) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from matplotlib>=3.8.0->plotnine->prosodic) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from matplotlib>=3.8.0->plotnine->prosodic) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from matplotlib>=3.8.0->plotnine->prosodic) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from matplotlib>=3.8.0->plotnine->prosodic) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from matplotlib>=3.8.0->plotnine->prosodic) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from matplotlib>=3.8.0->plotnine->prosodic) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from matplotlib>=3.8.0->plotnine->prosodic) (3.2.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from pexpect>4.3->ipython->prosodic) (0.7.0)
# Requirement already satisfied: bidict>=0.21.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from python-socketio>=5.12.0->flask-socketio->prosodic) (0.23.1)
# Requirement already satisfied: python-engineio>=4.11.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from python-socketio>=5.12.0->flask-socketio->prosodic) (4.11.2)
# Requirement already satisfied: patsy>=0.5.6 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from statsmodels>=0.14.0->plotnine->prosodic) (1.0.1)
# Requirement already satisfied: dill>=0.3.9 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from multiprocess->logmap->prosodic) (0.3.9)
# Requirement already satisfied: csvw>=1.5.6 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from segments->phonemizer->prosodic) (3.5.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from stack_data->ipython->prosodic) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from stack_data->ipython->prosodic) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from stack_data->ipython->prosodic) (0.2.3)
# Requirement already satisfied: setuptools in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from zope.event->gevent->prosodic) (76.0.0)
# Requirement already satisfied: isodate in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (0.7.2)
# Requirement already satisfied: rfc3986<2 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (1.5.0)
# Requirement already satisfied: uritemplate>=3.0.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (4.1.1)
# Requirement already satisfied: babel in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (2.17.0)
# Requirement already satisfied: requests in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (2.32.3)
# Requirement already satisfied: language-tags in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (1.2.0)
# Requirement already satisfied: rdflib in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (7.1.3)
# Requirement already satisfied: colorama in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (0.4.6)
# Requirement already satisfied: jsonschema in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (4.23.0)
# Requirement already satisfied: simple-websocket>=0.10.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from python-engineio>=4.11.0->python-socketio>=5.12.0->flask-socketio->prosodic) (1.1.0)
# Requirement already satisfied: wsproto in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio>=5.12.0->flask-socketio->prosodic) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer->prosodic) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer->prosodic) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer->prosodic) (0.23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from requests->csvw>=1.5.6->segments->phonemizer->prosodic) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from requests->csvw>=1.5.6->segments->phonemizer->prosodic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from requests->csvw>=1.5.6->segments->phonemizer->prosodic) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from requests->csvw>=1.5.6->segments->phonemizer->prosodic) (2024.12.14)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/bsg25/.pyenv/versions/3.13.1/lib/python3.13/site-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio>=5.12.0->flask-socketio->prosodic) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import prosodic
prosodic.logger.setLevel('ERROR')
# Out:
# [0.05s] hashstash.config.get_compresser(): Compression library lz4 is not installed. Defaulting to zlib. To install lz4, run: pip install lz4

# %%
#parseloop for single txt file

import pandas as pd
import prosodic
prosodic.logger.setLevel('ERROR')

#set meter

constraints={
    'w_peak':2.0,
    'w_stress':0.0,
    's_unstress':0.0,
    'unres_across':1.0,
    'unres_within':1.0,
    'pentameter':10.0,
    'iambic':10.0,
}
meter = prosodic.Meter(
    constraints=constraints,
    resolve_optionality=True,
    max_s=1,
    max_w=2,
)

meter.to_dict()

# Create an empty DataFrame with the desired column headers
column_headers = ["line_txt", "txt", "meter", "stress", "score", "num_viols", "ambig"]
df = pd.DataFrame(columns=column_headers)

# Loop through input lines and add data to DataFrame

with open('/Users/bsg25/Library/CloudStorage/OneDrive-YaleUniversity/TrochAIc/ChunkedECEP/ecepip119.txt', 'r') as f:  # Replace with your file path
        for line in f:
            line = line.strip()  # Remove leading/trailing whitespace

            line = prosodic.Text(line)  # Process with prosodic.Text()
            parses = line.parse()
            parse_dict = parses[0].best_parse.attrs

    # Extract data from the first parse (modify if you need data from other parses)

            new_dict = {key: parse_dict[key] for key in column_headers if key in parse_dict}

    # Append data to DataFrame
            df = pd.concat([df, pd.DataFrame([new_dict])], ignore_index=True)
                


    # Save the DataFrame to a CSV file
        df.to_csv('/Users/bsg25/Library/CloudStorage/OneDrive-YaleUniversity/TrochAIc/ChunkedECEP/csv_outputs/ecepip119.csv', index=False)

# %%
#chunk parser

import os
import pandas as pd
import prosodic
prosodic.logger.setLevel('ERROR')

# Set meter
constraints = {
    'w_peak': 2.0,
    'w_stress': 0.0,
    's_unstress': 0.0,
    'unres_across': 1.0,
    'unres_within': 1.0,
    'pentameter': 10.0,
    'iambic': 2.0,
}
meter = prosodic.Meter(
    constraints=constraints,
    resolve_optionality=True,
    max_s=1,
    max_w=2,
)

# Column headers for the DataFrame
column_headers = ["line_txt", "txt", "meter", "stress", "score", "num_viols", "ambig"]

# Input directory containing the files
input_dir = '/Users/bsg25/Library/CloudStorage/OneDrive-YaleUniversity/TrochAIc/ChunkedECEP/'  # Replace with your directory path

# Loop through each file in the directory
for filename in os.listdir(input_dir):
    if filename.endswith(".txt"):  # Process only .txt files
        filepath = os.path.join(input_dir, filename)

        # Create an empty DataFrame for the current file
        df = None
        df = pd.DataFrame(columns=column_headers)

        # Read and parse the lines in the file
        with open(filepath, 'r') as f:
            for line in f:
                line = line.strip()
                line = prosodic.Text(line)
                parses = line.parse()
                parse_dict = parses[0].best_parse.attrs

                # Extract data from the parse
                new_dict = {key: parse_dict[key] for key in column_headers if key in parse_dict}

                # Append data to DataFrame
                df = pd.concat([df, pd.DataFrame([new_dict])], ignore_index=True)

        # Output CSV with the same name as input file (but with .csv extension)
        output_filename = os.path.splitext(filename)[0] + ".csv"
        output_filepath = os.path.join('/Users/bsg25/Library/CloudStorage/OneDrive-YaleUniversity/TrochAIc/ChunkedECEP/csv_outputs', output_filename)
        df.to_csv(output_filepath, index=False)
    
        print(f"Processed: {filename}")

print("Processing complete.")
